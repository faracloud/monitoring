# %%
try:
    import urllib.request as urllib2
except ImportError:
    import urllib2

response = urllib2.urlopen('http://www.iranserver.com/dedicated-server/iran/')
content = response.read()
# lines = content.decode("utf8").split("\n")

for temp in lines:
    print (temp)
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js"> <!--<![endif]-->
#     <head>
#         <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#         <meta name="robots" content="noodp"/>
#         <meta name="author" content="http://www.greenweb.ir" />
#         <link rel="publisher" href="https://plus.google.com/+Iranservercom/">
#                 <meta http-equiv="X-UA-Compatible" content="IE=edge" />
#
#         <title>سرور اختصاصی ایران خرید سرور اختصاصی پارس آنلاین افرانت و مخابرات | ایران سرور</title>
# <meta name="description" content="خدمات سرور اختصاصی ایران ویندوز 2008 و ویندوز 2012 و سرور اختصاصی لینوکس ایران در ایران سرور ارائه میگردد. سرور اختصاصی فرانت پارس آنلاین و مخابرات"/>
# <meta name="robots" content="index, follow" />
#         <link href="http://iranserver.com/css/jquery.mCustomScrollbar.css" rel="stylesheet" />
#
#
#              <link rel="stylesheet" href="http://iranserver.com/css/tipso.min.css" type="text/css" />
#             <link rel="stylesheet" href="http://iranserver.com/css/prettyPhoto.css" type="text/css"  />
#             <link rel="stylesheet" href="http://iranserver.com/css/style-inside.css?ver=4.1" type="text/css" />
#
#
#
#
#          <script src="http://iranserver.com/js/vendor/modernizr-2.6.2.min.js"></script>
#
#     </head>
#     <body>
#        <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Organization",
#   "name": "Iranserver",
#   "url": "http://www.iranserver.com",
#   "sameAs": [
#     "https://www.facebook.com/iranserver",
#     "https://www.instagram.com/iranserver/",
#     "https://www.linkedin.com/company/iranserver",
#     "https://twitter.com/iranserver",
#     "https://plus.google.com/+Iranservercom"
#
#   ]
# }
# </script>
# <script type="application/ld+json">
#          {
#                   "@context": "http://schema.org",
#                   "@type": "Organization",
#                   "url": "http://www.iranserver.com/",
#                   "logo": "http://www.iranserver.com/logo.png",
#                   "contactPoint": [{
#                     "@type": "ContactPoint",
#                     "telephone": "+98-51-37673600",
#                     "contactType": "customer service"
#  }]
#  }
# </script>
#         <!--[if lt IE 7]>
#             <p class="chromeframe">You are using an <strong>outdated</strong> browser. Please <a href="http://browsehappy.com/">upgrade your browser</a> or <a href="http://www.google.com/chromeframe/?redirect=true">activate Google Chrome Frame</a> to improve your experience.</p>
#         <![endif]-->
#         <!-- HEADER -->
#         <div class="header cover">
#             <div class="support_bar">
#                 <div class="content-header cover">
#                     <div class="right font-face">
#                         <ul class="nav_top cover">
#                             <li onclick="ga('send', 'event', 'navbar', 'onlinechat');">
#                                 <a id="mibew-agent-button" href="http://webchat.iranserver.com/chat?locale=fa&amp;style=iranserver" target="_blank" onclick="Mibew.Objects.ChatPopups['556085ac9683ba30'].open();return false;"><img src="http://webchat.iranserver.com/b?i=mblue&amp;lang=fa" alt="" /></a><script async type="text/javascript" src="http://webchat.iranserver.com/js/compiled/chat_popup.js"></script><script type="text/javascript">Mibew.ChatPopup.init({"id":"556085ac9683ba30","url":"http:\/\/webchat.iranserver.com\/chat?locale=fa&style=iranserver","preferIFrame":false,"modSecurity":false,"height":480,"width":640,"resizable":true,"styleLoader":"http:\/\/webchat.iranserver.com\/chat\/style\/popup\/iranserver"});</script><div id="mibew-invitation"></div><script async type="text/javascript" src="http://webchat.iranserver.com/js/compiled/widget.js"></script><script type="text/javascript">Mibew.Widget.init({"inviteStyle":"http:\/\/webchat.iranserver.com\/styles\/invitations\/iranserver\/invite.css","requestTimeout":10000,"requestURL":"http:\/\/webchat.iranserver.com\/widget","locale":"fa","visitorCookieName":"MIBEW_VisitorID"})</script>
#                             </li>
#                                                         <li>
#                                 <a  class="portal" onclick="ga('send', 'event', 'navbar', 'loginportal');">پورتال مشتریان</a>
#                                 <div class="login">
#                                                                         <form name="form1" id="userform" action="https://hub.iranserver.com/dologin.php" method="post">
#                                         <label>نام کاربری</label>
#                                         <input name="username" type="text" />
#                                         <label>کلمه عبور</label>
#                                         <input name="password" type="password" />
#                                         <style>.nav_top li .login { height: 390px !important; }</style>
#                                                       <label>تصویر امنیتی</label>
#                                                       <input name='code' type='text' class='captchatext' autocomplete='off' />
#                                                       <img onclick='this.src = this.src' title='جهت تغییر کد کلیک کنید' class='captchaimg' src='https://hub.iranserver.com/includes/verifyimage.php'>                                        <a href="https://hub.iranserver.com/pwreset.php" target="_blank">رمز عبور را فراموش کرده اید؟</a>
#                                         <input type="submit" value="ورود به پورتال" />
#                                         <input type="checkbox" name="rememberme" />ذخیره
#                                         <a href="https://hub.iranserver.com/register.php" style="display:inline;padding-right:7px;" target="_blank">عضویت</a>
#                                     </form>
#                                 </div>
#                             </li>
#                             <li>
#                                 <a href="https://hub.iranserver.com/bank-account-number.php" target="_blank">شماره حساب‌ها</a>
#                             </li>
#                             <li>
#                                 <a href="http://iranserver.com/term-of-service/">شرایط استفاده از خدمات</a>
#                             </li>
#                                                     </ul>
#                     </div>
#                                         <div class="left font-face-roya tel">
#                          <a href="http://iranserver.com/contact-us/"> 37673600 51 98+ </a>
#                     </div>
#                                     </div>
#             </div>
#             <div class="main_navigation_menu">
#                 <div class="content-header cover">
#                     <div class="logo">
#                         <a href="http://iranserver.com/">
#                             <h1>ایران سرور</h1>
#                         </a>
#                     </div>
#                                         <ul class="main-menu font-face cover">
#                         <li><a href="http://iranserver.com/dedicated-server/" title="سرور اختصاصی">سرور اختصاصی</a></li>
#                         <li><a href="http://iranserver.com/vps/" title="سرور مجازی">سرور مجازی</a></li>
#                         <li><a href="http://iranserver.com/web-hosting/" title="هاست">هاست</a></li>
#                         <li><a href="http://iranserver.com/domains/" title="ثبت دامنه">ثبت دامنه</a></li>
#                          <li><a href="http://iranserver.com/visa-card/" title="ویزا کارت">ویزا کارت</a></li>
#                         <li><a href="http://iranserver.com/other-services/">خدمات دیگر</a></li>
#                     </ul>
#                                     </div>
#             </div>
#
#         </div><!-- ./header -->    <div class="img-top">
#         <img src="http://iranserver.com/img/iranserver_mini_data_center.jpg" alt="iranserver_mini_data_center" width="100%" height="100%">
#         <a href="http://status.iranserver.com/" target="_blank" onclick="ga('send', 'event', 'header', 'status');"><div class="stauts-server">وضعیت سرورها</div></a>
#         <h2 class="stauts-server-txt">سرور اختصاصی ایران</h2>
#     </div><!-- ./img-top -->
# 	<div class="back_services font-face">
# 		<ul class="cover">
# 			  <li class="active"><a href="http://iranserver.com/dedicated-server/iran/" title="سرور اختصاصی ایران">ایران<span class="icon-active-menu"></span></a></li>
#               <li><a href="http://iranserver.com/dedicated-server/germany/" title="سرور اختصاصی آلمان">آلمان</a></li>
#               <li><a href="http://iranserver.com/dedicated-server/france/" title="سرور اختصاصی فرانسه">فرانسه</a></li>
#               <li><a href="http://iranserver.com/dedicated-server/canada/" title="سرور اختصاصی کانادا">کانادا</a></li>
#               <li><a href="http://iranserver.com/dedicated-server/usa/" title="سرور اختصاصی آمریکا">آمریکا</a></li>
#               <li><a href="http://iranserver.com/dedicated-server/ibm/" title="سرور اختصاصی IBM">IBM</a></li>
#               <li><a href="http://iranserver.com/dedicated-server/server-management/">مدیریت سرور</a></li>
#               <li><a href="http://iranserver.com/dedicated-server/co-location/">فضای رک</a></li>
#               <li><a href="http://iranserver.com/datacenter-tour/" target="_blank">معرفی دیتاسنتر</a></li>
#               <li><a href="http://iranserver.com/dedicated-server/compare/" title="مقایسه سرور اختصاصی">مقایسه</a></li>
#               <li><a href="http://iranserver.com/promotions/" target="_blank">فروش ویژه</a></li>
# 		</ul>
# 	</div>
# 	<!-- content-panels -->
# 	<div class="content-panels cover iran">
# 		<div class="title">
#           <h3>سرور اختصاصی لینوکس و ویندوز ایران</h3>
#         </div>
#         <div class="description cover">
#             <p>
#                 <span class="font-face">استفاده از سرورهای اختصاصی داخل کشور باعث می‌شود که سرعت دسترسی کاربران ایرانی به اطلاعات سرور شما تا ۴ برابر افزایش پیدا کند. ایران‌سرور با ایجاد یک شبکه‌ی خصوصی و استفاده از بهترین تجهیزات سخت‌افزاری در سه دیتاسنتر<a href="http://iranserver.com/datacenter-tour/" target="_blank"> افرانت</a>، <a href="http://iranserver.com/datacenter-tour/" target="_blank">پارس‌آنلاین</a> و <a href="http://iranserver.com/datacenter-tour/" target="_blank">مخابرات</a>، خدمات متنوعی را به شما ارائه می‌دهد. استفاده از سرورهای جدید با برندهای معتبر جهانی تضمین کننده‌ی کیفیت خدمات ما خواهد بود. افتخار ما ارائه خدمات قابل رقابت با دیتاسنترهای خارجی در داخل ایران می‌باشد.</span>
#      			<span class="bg-description"></span>
#             </p>
#         </div>
#         <div class="first" id="first">
#           <table id="headtable">
#               <tr>
#                 <td  width="155">نام سرور</td>
#                 <td  width="155">ایران۷ </td>
#                 <td  width="155">ایران۲۰</td>
# <!--                <td  width="120">ایران۲۱</td>-->
#                 <td  class="green" width="155">ایران ۲۲</td>
#                 <td class="green"  width="155">ایران۱۴</td>
#                 <td  width="155">ایران۱۹</td>
# <!--                <td  width="91">ایران۱۷</td>-->
#             </tr>
#           </table>
#         </div>
#         <div class="hole" id="hole">
#         <table id="panels" class="panels tahoma">
#         	<tr class="nonedis">
#         		<td  width="149">نام سرور</td>
#         		<td  width="155">ایران۷ </td>
#         		<td  width="155">ایران۲۰</td>
# <!--                <td  width="120">ایران۲۱</td>-->
#                 <td  class="green" width="154">ایران ۲۲</td>
#         		<td class="green" width="155">ایران۱۴</td>
#         		<td width="155">ایران۱۹</td>
# <!--                <td  width="91">ایران۱۷</td>-->
#
#         	</tr>
#         	<tr>
#         		<td width="149">CPU</td>
#         		<td width="155">Xeon 3430</td>
#         		<td width="155">Xeon L5520</td>
# <!--                <td width="120">Xeon L5520</td>-->
#                 <td class="green-light" width="154">Xeon 5540</td>
#         		<td class="green-light" width="155">2x Xeon L5520</td>
#         	    <td width="155">2x Xeon5650</td>
# <!--                <td width="91">2x Xeon X5660</td>-->
#         	</tr>
#         	<tr>
#         		<td>RAM</td>
#         		<td>۸  گیگابایت</td>
#         		<td>۲۴ گیگابایت</td>
# <!--                <td>۳۲ گیگابایت</td>-->
#                 <td class="green">۳۲ گیگابایت </td>
#         		<td class="green">۳۲ گیگابایت</td>
#         		<td >۷۲ گیگابایت</td>
# <!--                <td>۶۴ گیگابایت</td>-->
#         	</tr>
#         	<tr>
#         		<td>هارد دیسک</td>
#         		<td>2x500G SATA</td>
#         		<td>2x1TB SATA</td>
# <!--                <td>2x1TB SATA<br>1x120G SSD</td>-->
#                 <td class="green-light" width="120">2x1TB SATA + 2x240G SSD</td>
#         		<td class="green-light">2x1TB SATA</td>
#         		<td>4x1TB SAS</td>
# <!--                <td>4x3TB SATA</td>-->
#         	</tr>
#             <tr>
#                 <td data-tipso="پهنای‌باند در واقع همان سرعت ارتباطی سرور شما با اینترنت می‌باشد." class="beforeShow">پهنای باند </td>
#                 <td>۱۰۰ مگابیت</td>
#                 <td>۱۰۰ مگابیت</td>
# <!--                <td>۱۰۰ مگابیت</td>-->
#                 <td class="green">۱۰۰ مگابیت</td>
#                 <td class="green">۱۰۰ مگابیت</td>
#                 <td>۱۰۰ مگابیت</td>
# <!--                <td>۱۰۰ مگابیت</td>-->
#             </tr>
#             <tr>
#                 <td data-tipso="سرور شما در هر ماه میلادی مجاز است حداکثر میزان مشخص شده‌ی ترافیک شبکه را استفاده کند. ترافیک مصرفی از مجموع ارسال و دریافتهای سرور حاصل می‌شود." class="beforeShow">ترافیک ماهیانه </td>
#                 <td>۱ ترابایت</td>
#                 <td>۳ ترابایت</td>
# <!--                <td>۳ ترابایت</td>-->
#                 <td class="green-light">۳ ترابایت</td>
#                 <td class="green-light">۳ ترابایت</td>
#                 <td>۳ ترابایت</td>
# <!--                <td>۳ ترابایت</td>-->
#             </tr>
#             <tr class="dc">
#                 <td><a href="http://iranserver.com/datacenter-tour/" target="_blank">دیتاسنتر</a> </td>
#                 <td><a href="http://iranserver.com/datacenter-tour/" target="_blank">پارس آنلاین / افرانت</a></td>
#                 <td><a href="http://iranserver.com/datacenter-tour/" target="_blank">پارس آنلاین / افرانت</a></td>
# <!--                <td><a href="datacenter-tour/" target="_blank">پارس آنلاین / افرانت</a></td>-->
#                 <td class="green"><a href="http://iranserver.com/datacenter-tour/" target="_blank">پارس آنلاین / افرانت</a></td>
#                 <td class="green"><a href="http://iranserver.com/datacenter-tour/" target="_blank">پارس آنلاین / افرانت</a></td>
#                 <td><a href="http://iranserver.com/datacenter-tour/" target="_blank">پارس آنلاین / افرانت</a></td>
# <!--                <td><a href="http://iranserver.com/datacenter-tour/" target="_blank">پارس آنلاین / افرانت</a></td>-->
#             </tr>
#         	<tr class="dc">
#         		<td><a href="http://iranserver.com/support/">پشتیبانی</a></td>
#                 <td><a href="http://iranserver.com/support/">سطح یک</a></td>
#                 <td><a href="http://iranserver.com/support/">سطح یک</a></td>
# <!--                <td><a href="support/">سطح یک</a></td>-->
#                 <td class="green-light"><a href="http://iranserver.com/support/">سطح یک</a></td>
#         		<td class="green-light"><a href="http://iranserver.com/support/">سطح یک</a></td>
#                 <td><a href="http://iranserver.com/support/">سطح یک</a></td>
# <!--                <td><a href="http://iranserver.com/support/">سطح یک</a></td>-->
#         	</tr>
#             <tr>
#                 <td>کنترل پنل</td>
#                 <td><a href="http://iranserver.com/control-panel/" target="_blank">انتخابی</a></td>
#                 <td><a href="http://iranserver.com/control-panel/" target="_blank">انتخابی</a></td>
# <!--                <td><a href="control-panel/" target="_blank">انتخابی</a></td>-->
#                 <td class="green"><a href="http://iranserver.com/control-panel/" target="_blank">انتخابی</a></td>
#                 <td class="green"><a href="http://iranserver.com/control-panel/" target="_blank">انتخابی</a></td>
#                 <td><a href="http://iranserver.com/control-panel/" target="_blank">انتخابی</a></td>
# <!--                <td><a href="http://iranserver.com/control-panel/" target="_blank">انتخابی</a></td>-->
#             </tr>
#             <tr>
#                 <td>سیستم عامل</td>
#                 <td><a href="http://iranserver.com/operating-system/" target="_blank">انتخابی</a></td>
#                 <td><a href="http://iranserver.com/operating-system/" target="_blank">انتخابی</a></td>
# <!--                <td><a href="operating-system/" target="_blank">انتخابی</a></td>-->
#                 <td class="green-light"><a href="http://iranserver.com/operating-system/" target="_blank">انتخابی</a></td>
#                 <td class="green-light"><a href="http://iranserver.com/operating-system/" target="_blank">انتخابی</a></td>
#                 <td><a href="http://iranserver.com/operating-system/" target="_blank">انتخابی</a></td>
# <!--                <td><a href="http://iranserver.com/operating-system/" target="_blank">انتخابی</a></td>                -->
#             </tr>
#             <tr>
#                 <td>برند</td>
#                 <td>Asus</td>
#                 <td>HP</td>
# <!--                <td>HP</td>-->
#                 <td class="green">HP</td>
#                 <td class="green">HP</td>
#                 <td>HP</td>
# <!--                <td>HP</td>                -->
#             </tr>
#            <tr>
#                 <td>مدت تحویل (روزکاری)</td>
#                 <td>۱ تا ۳</td>
#                 <td>۱ تا ۳</td>
# <!--                <td>۱ تا ۳</td>-->
#                 <td class="green-light">۱ تا ۳</td>
#                 <td class="green-light">۱ تا ۳</td>
#                 <td>۱ تا ۳</td>
# <!--                <td>۱ تا ۳</td>              -->
#             </tr>
#         	<tr>
#         		<td data-tipso="در ابتدای خرید و تحویل سرور مبلغی تحت عنوان «هزینه‌ی راه‌اندازی اولیه سرور» دریافت می‌شود. این مبلغ وابسته به سرور و دیتاسنتر متفاوت می‌باشد." class="beforeShow">هزینه‌ی راه‌اندازی (تومان)</td>
#         		<td>۵۰,۰۰۰</td>
#         		<td>۵۰,۰۰۰</td>
# <!--                <td>۵۰,۰۰۰</td>-->
#                 <td class="green">۵۰,۰۰۰</td>
#         		<td class="green">۵۰,۰۰۰</td>
#                 <td>۵۰,۰۰۰</td>
# <!--                <td>۵۰,۰۰۰</td>-->
#         	</tr>
#             <tr>
#                 <td>هزینه‌ی ماهیانه (تومان)</td>
#                 <td>۴۰۲,۵۰۰</td>
#                 <td>۴۷۲,۰۰۰</td>
# <!--                <td>۵۹۰,۰۰۰</td>-->
#                 <td class="green-light">۶۷۸,۵۰۰</td>
#                 <td class="green-light">۶۷۸,۵۰۰</td>
#                 <td>۱,۱۳۸,۰۰۰</td>
# <!--                <td>۱,۹۰۰,۰۰۰</td>-->
#             </tr>
#              <tr>
#                 <td>قیمت سخت افزار</td>
#                 <td><a href="http://iranserver.com/other-services/hardware/" target="_blank">کلیک کنید</a></td>
#                 <td><a href="http://iranserver.com/other-services/hardware/" target="_blank">کلیک کنید</a></td>
# <!--                <td><a href="other-services/hardware/" target="_blank">کلیک کنید</a></td>-->
#                 <td class="green"><a href="http://iranserver.com/other-services/hardware/" target="_blank">کلیک کنید</a></td>
#                 <td class="green"><a href="http://iranserver.com/other-services/hardware/" target="_blank">کلیک کنید</a></td>
#                 <td><a href="http://iranserver.com/other-services/hardware/" target="_blank">کلیک کنید</a></td>
# <!--                <td><a href="http://iranserver.com/other-services/hardware/" target="_blank">کلیک کنید</a></td>-->
#             </tr>
#         	<tr>
#         		<td>تمـام قـیمت هـــــا به تومان می باشد.</td>
#         		<td><a href="https://hub.iranserver.com/cart.php?a=add&pid=351" target="_blank" onclick="ga('send', 'event', 'planstable', 'ordernow');">سفارش</a></td>
#         		<td><a href="https://hub.iranserver.com/cart.php?a=add&pid=414" target="_blank" onclick="ga('send', 'event', 'planstable', 'ordernow');">سفارش</a></td>
# <!--                <td><a href="https://hub.iranserver.com/cart.php?a=add&pid=415" target="_blank" onclick="ga('send', 'event', 'planstable', 'ordernow');">سفارش</a></td>-->
#                 <td class="green-light"><a href="https://hub.iranserver.com/cart.php?a=add&pid=441" target="_blank" onclick="ga('send', 'event', 'planstable', 'ordernow');">سفارش</a></td>
#         		<td class="green-light"><a href="https://hub.iranserver.com/cart.php?a=add&pid=287" target="_blank" onclick="ga('send', 'event', 'planstable', 'ordernow');">سفارش</a></td>
#                 <td><a href="https://hub.iranserver.com/cart.php?a=add&pid=400" target="_blank" onclick="ga('send', 'event', 'planstable', 'ordernow');">سفارش</a></td>
# <!--                <td><a href="https://hub.iranserver.com/cart.php?a=add&pid=362" target="_blank" onclick="ga('send', 'event', 'planstable', 'ordernow');">سفارش</a></td>-->
#         	</tr>
#         </table>
#         <a  class="details" onclick="ga('send', 'event', 'planstable', 'moredetails');">جزییات بیشتر</a>
#         <div class="more-detail cover">
#           <table id="panels2" class="tahoma tbl">
#             <tr><td colspan="10" class="titr">جزئیات سخت افزاری</td></tr>
#             <tr>
#                 <td  width="153">تعداد CPU Core</td>
#                 <td  width="155">۴</td>
#                 <td  width="155">۴</td>
# <!--                <td  width="120">۴</td>-->
#                 <td  class='green' width="154">۴</td>
#                 <td class='green' width="155">۲x۴</td>
#                 <td width="155">۲x۶</td>
# <!--                <td  width="91">۲x۶</td>-->
#             </tr>
#             <tr>
#                 <td>تعداد CPU Threads</td>
#                 <td>۴</td>
#                 <td>۸</td>
# <!--                <td>۸</td>-->
#                 <td class='green-light'>۸</td>
#                 <td class='green-light'>۲x۸</td>
#                 <td>۲x۱۲</td>
# <!--                <td>۲x۱۲</td>-->
#             </tr>
#             <tr>
#                 <td>سرعت پردازش (GHz)</td>
#                 <td>2.4</td>
#                 <td>2.26</td>
# <!--                <td>2.26</td>-->
#                 <td class='green'>2.53</td>
#                 <td class='green'>2.26</td>
#                 <td>2.66</td>
# <!--                <td>2.8</td>-->
#             </tr>
#             <tr>
#                 <td data-tipso="CPUهای جدید دارای امکان مجازی‌سازی سخت‌افزاری می‌باشند؛ فعال بودن این تکنولوژی به شما امکان استفاده از مجازی‌سازهای معروف مانندXen  و KVM را خواهد داد." class="beforeShow">امکان مجازی‌سازی </td>
#                 <td><a target="_blank" href="http://iranserver.com/dedicated-server/virtualization/">جزئیات</a></td>
#                 <td><a target="_blank" href="http://iranserver.com/dedicated-server/virtualization/">جزئیات</a></td>
# <!--                <td><a target="_blank" href="dedicated-server/virtualization/">جزئیات</a></td>-->
#                 <td class='green-light'><a target="_blank" href="http://iranserver.com/dedicated-server/virtualization/">جزئیات</a></td>
#                 <td class='green-light'><a target="_blank" href="http://iranserver.com/dedicated-server/virtualization/">جزئیات</a></td>
#                 <td><a target="_blank" href="http://iranserver.com/dedicated-server/virtualization/">جزئیات</a></td>
# <!--                <td><a target="_blank" href="http://iranserver.com/dedicated-server/virtualization/">جزئیات</a></td>-->
#             </tr>
#             <tr>
#                 <td data-tipso="درصورتی که سرور از انواع RAIDهای سخت‌افزاری پشتیبانی کند، شما بدون نیاز به سیستم‌عامل و به‌صورت سخت‌افزاری می‌توانید از RAID استفاده نمایید. برای استفاده از RAID، سرور باید حداقل دو هارد دیسک داشته باشد." class="beforeShow">امکان RAID سخت‌افزاری </td>
#                 <td><span class="ok"></span></td>
#                 <td><span class="ok"></span></td>
# <!--                <td><span class="ok"></span></td>-->
#                 <td class='green'><span class="ok"></span></td>
#                 <td class='green'><span class="ok"></span></td>
#                 <td><span class="ok"></span></td>
# <!--                <td><span class="ok"></span></td>-->
#             </tr>
#             <tr>
#                 <td data-tipso="می‌توانید با استفاده از امکانات سیستم‌عامل از RAID نرم‌افزاری استفاده کنید. برای استفاده از RAID، سرور باید حداقل دو هارد دیسک داشته باشد." class="beforeShow">امکان RAID نرم‌افزاری</td>
#                 <td><span class="ok"></span></td>
#                 <td><span class="ok"></span></td>
# <!--                <td><span class="ok"></span></td>-->
#                 <td class='green-light'><span class="ok"></span></td>
#                 <td class='green-light'><span class="ok"></span></td>
#                 <td><span class="ok"></span></td>
# <!--                <td><span class="ok"></span></td>-->
#             </tr>
#             <tr>
#                 <td>سرعت کارت شبکه</td>
#                 <td>۱ گیگابیت</td>
#                 <td>۱ گیگابیت</td>
# <!--                <td>۱ گیگابیت</td>-->
#                 <td class='green'>۱ گیگابیت</td>
#                 <td class='green'>۱ گیگابیت</td>
#                 <td>۱ گیگابیت</td>
# <!--                <td>۱ گیگابیت</td>-->
#             </tr>
#             <tr><td colspan="9" class="titr">جزئیات شبکه</td></tr>
#             <tr>
#                 <td>اینترانت</td>
#                 <td><a href="http://iranserver.com/dedicated-server/iran/interanet/" target="_blank">انتخابی </a></td>
#                 <td><a href="http://iranserver.com/dedicated-server/iran/interanet/" target="_blank">انتخابی </a></td>
# <!--                <td><a href="dedicated-server/iran/interanet/" target="_blank">انتخابی </a></td>-->
#                 <td class='green-light'><a href="http://iranserver.com/dedicated-server/iran/interanet/" target="_blank">انتخابی </a></td>
#                 <td class='green-light'><a href="http://iranserver.com/dedicated-server/iran/interanet/" target="_blank">انتخابی </a></td>
#                 <td><a href="http://iranserver.com/dedicated-server/iran/interanet/" target="_blank">انتخابی </a></td>
# <!--                <td><a href="http://iranserver.com/dedicated-server/iran/interanet/" target="_blank">انتخابی </a></td>-->
#             </tr>
#             <tr>
#                 <td data-tipso="تعداد کابل‌های برفرار کننده‌ی ارتباط بین سرور و سوییچ است. در صورت نیاز به سرویس اینترنت و اینترانت به‌صورت همزمان شما نیاز به دو اتصال شبکه خواهید داشت." class="beforeShow">تعداد اتصال به شبکه</td>
#                 <td>یک عدد </td>
#                 <td>یک عدد </td>
# <!--                <td>یک عدد </td>-->
#                 <td class='green'>یک عدد </td>
#                 <td class='green'>یک عدد </td>
#                 <td>یک عدد </td>
# <!--                <td>یک عدد </td>-->
#             </tr>
#             <tr>
#                 <td data-tipso="یکی از مهمترین قطعات تضمین کننده‌ی کیفیت شبکه، سخت‌افزارهای استفاده شده در زیرساخت شبکه می‌باشند. استفاده از برندهای معتبر جهانی نوید بخش آسودگی خیال در استفاده از سرور خواهد بود." class="beforeShow">زیرساخت شبکه</td>
#                 <td>Cisco Catalyst </td>
#                 <td>Cisco Catalyst</td>
# <!--                <td>Cisco Catalyst</td>-->
#                 <td class='green-light'>Cisco Catalyst</td>
#                 <td class='green-light'>Cisco Catalyst </td>
#                 <td>Cisco Catalyst</td>
# <!--                <td>Cisco Catalyst</td>-->
#             </tr>
#             <tr>
#                 <td data-tipso="بصورت پیش‌فرض این تعداد IP به سرور شما اختصاص داده می‌شود." class="beforeShow">تعداد آدرس IP</td>
#                 <td>یک عدد </td>
#                 <td>یک عدد</td>
# <!--                <td>یک عدد</td>-->
#                 <td class='green'>یک عدد</td>
#                 <td class='green'>یک عدد </td>
#                 <td>یک عدد</td>
# <!--                <td>یک عدد</td>-->
#             </tr>
#              <tr>
#                 <td data-tipso="با توجه به محدودیت‌های موجود در استفاده از IP V4، دیتاسنتر حداکثراین تعداد IP را به سرور اختصاص خواهد داد. در صورت نیاز باید درخواست IP اضافه را پس از تحویل سرور بصورت جداگانه به بخش فروش ارسال نمایید." class="beforeShow">حداکثر تعداد IP تک</td>
#                 <td>۵ عدد</td>
#                 <td>۵ عدد</td>
# <!--                <td>۵ عدد</td>-->
#                 <td class='green-light'>۵ عدد</td>
#                 <td class='green-light'>۵ عدد</td>
#                 <td>۵ عدد</td>
# <!--                <td>۵ عدد</td>-->
#             </tr>
#             <tr>
#                 <td>هزینه‌ی IP اضافه</td>
#                 <td>۵,۰۰۰ تومان  </td>
#                 <td>۵,۰۰۰ تومان</td>
# <!--                <td>۵,۰۰۰ تومان</td>-->
#                 <td class='green'>۵,۰۰۰ تومان</td>
#                 <td class='green'>۵,۰۰۰ تومان</td>
#                 <td>۵,۰۰۰ تومان</td>
# <!--                <td>۵,۰۰۰ تومان</td>-->
#             </tr>
#             <tr>
#                 <td data-tipso='IP بلاک بصورت Subnet ارائه می‌شود و از هر بلاک سه IP برای تنظیمات شبکه مورد استفاده قرار می‌گیرد. براساس قوانین دیتاسنتر هزینه سه آدرس فوق برعهده مشترک خواهد بود.' class="beforeShow">حداکثر IP در بلاک IP</td>
#                 <td>۳۲ عدد</td>
#                 <td>۳۲ عدد</td>
# <!--                <td>۳۲ عدد</td>-->
#                 <td class='green-light'>۳۲ عدد</td>
#                 <td class='green-light'>۳۲ عدد</td>
#                 <td>۳۲ عدد</td>
# <!--                <td>۳۲ عدد</td>              -->
#             </tr>
#             <tr><td colspan="9" class="titr">دیگر امکانات</td></tr>
#             <tr>
#                 <td data-tipso="دایرکت‌ادمین (DA) یکی از بهترین کنترل‌پنل‌های لینوکسی می‌باشد،‌ به دلیل عدم تحریم و مشکلات ناشی از آن، در ایران از محبوبیت بالایی برخوردار است. از ویژگی‌های مهم DA نیاز به منابع کم سرور و سرعت بالا می‌باشد." class="beforeShow">کنترل پنل رایگان</td>
#                 <td><a href="http://iranserver.com/control-panel/" target="_blank">DirectAdmin</a></td>
#                 <td><a href="http://iranserver.com/control-panel/" target="_blank">DirectAdmin</a></td>
# <!--                <td><a href="control-panel/" target="_blank">DirectAdmin</a></td>-->
#                 <td class='green'><a href="http://iranserver.com/control-panel/" target="_blank">DirectAdmin</a></td>
#                 <td class='green'><a href="http://iranserver.com/control-panel/" target="_blank">DirectAdmin</a></td>
#                 <td><a href="http://iranserver.com/control-panel/" target="_blank">DirectAdmin</a></td>
# <!--                <td><a href="http://iranserver.com/control-panel/" target="_blank">DirectAdmin</a></td>-->
#             </tr>
#             <tr>
#                 <td data-tipso="اسکریپت CXS قویترین اسکریپت آنتی شل(Antishell) میباشد که در سرورهای لینوکس نصب و فعال میگردد." class="beforeShow">CXS AntiShell (تومان)</td>
#                 <td><a href="http://blog.iranserver.com/what-is-cxs" target="_blank">۲۰,۰۰۰</a></td>
#                 <td><a href="http://blog.iranserver.com/what-is-cxs" target="_blank">۲۰,۰۰۰</a></td>
# <!--                <td><a href="http://blog.iranserver.com/what-is-cxs" target="_blank">۲۰,۰۰۰</a></td>-->
#                 <td class='green'><a href="http://blog.iranserver.com/what-is-cxs" target="_blank">۲۰,۰۰۰</a></td>
#                 <td class='green'><a href="http://blog.iranserver.com/what-is-cxs" target="_blank">۲۰,۰۰۰</a></td>
#                 <td><a href="http://blog.iranserver.com/what-is-cxs" target="_blank">۲۰,۰۰۰</a></td>
# <!--                <td><a href="http://blog.iranserver.com/what-is-cxs" target="_blank">۲۰,۰۰۰</a></td>-->
#             </tr>
#             <tr>
#                 <td>گارانتی بازگشت وجه</td>
#                 <td>۱۵روز</td>
#                 <td>۱۵روز</td>
# <!--                <td>۱۵روز</td>-->
#                 <td class='green'>۱۵روز</td>
#                 <td class='green'>۱۵روز</td>
#                 <td>۱۵روز</td>
# <!--                <td>۱۵روز</td>-->
#             </tr>
#             <tr>
#                 <td>انتقال رایگان</td>
#                 <td><a href="http://iranserver.com/website-transfer/" target="_blank"> جزئیات</a></td>
#                 <td><a href="http://iranserver.com/website-transfer/" target="_blank"> جزئیات</a></td>
# <!--                <td><a href="website-transfer/" target="_blank"> جزئیات</a></td>-->
#                 <td class='green-light'><a href="http://iranserver.com/website-transfer/" target="_blank"> جزئیات</a></td>
#                 <td class='green-light'><a href="http://iranserver.com/website-transfer/" target="_blank"> جزئیات</a></td>
#                 <td><a href="http://iranserver.com/website-transfer/" target="_blank"> جزئیات</a></td>
# <!--                <td><a href="http://iranserver.com/website-transfer/" target="_blank"> جزئیات</a></td>-->
#             </tr>
#             <tr>
#                 <td data-tipso="درصورتی که روند Boot شدن سرور با مشکل مواجه شود برای مشاهده‌ی خطای احتمالی نیاز به دسترسی به مانیتور و صفحه کلید خواهید داشت، اینکار توسط KVM انجام می‌شود، در واقع KVM دسترسی به صفحه کلید و مانیتور سرور از طریق اینترنت می‌باشد." class="beforeShow">ارائه KVM</td>
#                 <td> در صورت نیاز</td>
#                 <td> در صورت نیاز</td>
# <!--                <td> در صورت نیاز</td>-->
#                 <td class='green'> در صورت نیاز</td>
#                 <td class='green'> در صورت نیاز</td>
#                 <td> در صورت نیاز</td>
# <!--                <td> در صورت نیاز</td>             -->
#             </tr>
#             <tr>
#                 <td data-tipso="در مواقعی دسترسی به سرور قطع می‌شود و برای Boot شدن مجدد آن نیاز به Reboot خواهد بود. امکان Reboot آنلاین از طریق پورتال مشتریان ایران‌سرور اینکار را ساده کرده‌است." class="beforeShow">دسترسی Reboot</td>
#                 <td><span class="err"></span></td>
#                 <td><span class="ok"></span></td>
# <!--                <td><span class="ok"></span></td>-->
#                 <td class='green-light'><span class="ok"></span></td>
#                 <td class='green-light'><span class="ok"></span></td>
#                 <td><span class="ok"></span></td>
# <!--                <td><span class="ok"></span></td>-->
#             </tr>
#             <tr>
#                 <td data-tipso="درصورت فراموش نمودن رمز سرور، خراب شدن هارد دیسک‌ها، نیاز به کپی اطلاعات خاص و بسیاری موارد دیگر می‌توانید سرور را از شبکه Boot کرده و با استفاده از Rescue به آن SSH کنید." class="beforeShow">دسترسی Rescue</td>
#                 <td><span class="ok"></span></td>
#                 <td><span class="ok"></span></td>
# <!--                <td><span class="ok"></span></td>-->
#                 <td class='green'><span class="ok"></span></td>
#                 <td class='green'><span class="ok"></span></td>
#                 <td><span class="ok"></span></td>
# <!--                <td><span class="ok"></span></td>-->
#             </tr>
#             <tr>
#                 <td data-tipso="به دلایل مختلف ممکن است نیاز به نصب مجدد سیستم‌عامل پیدا نمایید، با استفاده از این امکان نصب مجدد بسیاری از سیستم‌عامل‌ها میسر خواهد بود." class="beforeShow">امکان نصب مجدد رایگان</td>
#                 <td><span class="ok"></span></td>
#                 <td><span class="ok"></span></td>
# <!--                <td><span class="ok"></span></td>-->
#                 <td class='green-light'><span class="ok"></span></td>
#                 <td class='green-light'><span class="ok"></span></td>
#                 <td><span class="ok"></span></td>
# <!--                <td><span class="ok"></span></td>             -->
#             </tr>
#             <tr>
#                 <td data-tipso="به‌دلایل سخت‌افزاری ممکن است سرور شما با مشکل مواجه شود، به‌همین دلیل پشتیبان‌گیری از اطلاعات مهم در فضایی خارج از سرور حیاتی می‌باشد. برای سهولت کار، ایران‌سرور در اغلب سرویس‌های خود فضای پشتیبان رایگان به مشتریان ارائه می‌دهد." class="beforeShow">فضای پشتیبان رایگان</td>
#                 <td><a href="http://iranserver.com/free-backup-space" target="_blank">۱۰۰ گیگابایت</a></td>
#                 <td><a href="http://iranserver.com/free-backup-space" target="_blank">۱۰۰ گیگابایت</a></td>
# <!--                <td><a href="free-backup-space" target="_blank">۱۰۰ گیگابایت</a></td>-->
#                 <td class='green'><a href="http://iranserver.com/free-backup-space" target="_blank">۱۰۰ گیگابایت</a></td>
#                 <td class='green'><a href="http://iranserver.com/free-backup-space" target="_blank">۱۰۰ گیگابایت</a></td>
#                 <td><a href="http://iranserver.com/free-backup-space" target="_blank">۱۰۰ گیگابایت</a></td>
# <!--                <td><a href="http://iranserver.com/free-backup-space" target="_blank">۱۰۰ گیگابایت</a></td>-->
#             </tr>
#             <tr>
#                 <td data-tipso="گراف ترافیک نشان دهنده‌ی میزان پهنای‌باند معرفی سرور شما در هر لحظه می‌باشد. با استفاده از گراف ترافیک براحتی می‌توانید متوجه حملات DoS و یا مصرف‌های غیر معمول ترافیک در سرور خود شوید." class="beforeShow">دسترسی به گراف ترافیک</td>
#                 <td><span class="ok"></span></td>
#                 <td><span class="ok"></span></td>
# <!--                <td><span class="ok"></span></td>-->
#                 <td class='green-light'><span class="ok"></span></td>
#                 <td class='green-light'><span class="ok"></span></td>
#                 <td><span class="ok"></span></td>
# <!--                <td><span class="ok"></span></td>               -->
#             </tr>
#              <tr>
#                 <td data-tipso="بررسی Ping  سرور شما بصورت مداوم توسط پشتیبان ایران‌سرور این امکان را فراهم می‌سازد که درصورت قطع شدن سرور در سریع‌ترین زمان ممکن از آن مطلع شوید." class="beforeShow">مانیتورینگ سرویس‌ها</td>
#                 <td><span class="ok"></span></td>
#                 <td><span class="ok"></span></td>
# <!--                <td><span class="ok"></span></td>-->
#                 <td class='green'><span class="ok"></span></td>
#                 <td class='green'><span class="ok"></span></td>
#                 <td><span class="ok"></span></td>
# <!--                <td><span class="ok"></span></td>-->
#             </tr>
#             <tr>
#         		<td>تمـام قـیمت هـــــا به تومان می باشد.</td>
#         		<td><a href="https://hub.iranserver.com/cart.php?a=add&pid=351" target="_blank" onclick="ga('send', 'event', 'planstable', 'ordernow');">سفارش</a></td>
#         		<td><a href="https://hub.iranserver.com/cart.php?a=add&pid=414" target="_blank" onclick="ga('send', 'event', 'planstable', 'ordernow');">سفارش</a></td>
# <!--                <td><a href="https://hub.iranserver.com/cart.php?a=add&pid=415" target="_blank" onclick="ga('send', 'event', 'planstable', 'ordernow');">سفارش</a></td>-->
#                 <td class='green-light'><a href="https://hub.iranserver.com/cart.php?a=add&pid=441" target="_blank" onclick="ga('send', 'event', 'planstable', 'ordernow');">سفارش</a></td>
#         		<td class='green-light'><a href="https://hub.iranserver.com/cart.php?a=add&pid=287" target="_blank" onclick="ga('send', 'event', 'planstable', 'ordernow');">سفارش</a></td>
#                 <td><a href="https://hub.iranserver.com/cart.php?a=add&pid=400" target="_blank" onclick="ga('send', 'event', 'planstable', 'ordernow');">سفارش</a></td>
# <!--                <td><a href="https://hub.iranserver.com/cart.php?a=add&pid=364" target="_blank" onclick="ga('send', 'event', 'planstable', 'ordernow');">سفارش</a></td>-->
#         	</tr>
#         </table>
#         </div>
#         </div>
#         <br><br>
#         <div class="text2">
#             <ul>
#                 <li>ترافیک مصرفی در ابتدای هر ماه میلادی صفر میگردد و به تاریخ تمدید سرور بی ارتباط می‌باشد.</li>
#                 <li>تعویض قطعات معیوب توسط ایران‌سرور انجام می‌گردد.</li>
#                 <li>امکان دانلود بسته‌های نرم‌افزاری از داخل شبکه با سرعت بسیاربالا فراهم است.</li>
#                 <li>درصورت نیاز به ترافیک بیشتر، لطفا با بخش فروش تماس بگیرید.</li>
#                 <li>امکان پرداخت بیش از یک ماه فراهم است.</li>
#                 <li>امکان واگذاری <a href="http://iranserver.com/other-services/hardware/" target="_blank">سخت‌افزار</a> بصورت اجاره به شرط تملیک وجود دارد؛ برای اطلاعات بیشتر با بخش فروش تماس حاصل فرمایید.</li>
#                 <li>این سرویس‌ها برای راه‌اندازی VPN مناسب نمی‌باشد.</li>
#                 <li>ترافیک نامتقارن و مناسب وب هاستینگ می‌باشد.</li>
#             </ul>
#         </div>
# 	</div><!-- ./content-panels -->
# 	<!-- FOOTER -->
#     <div class="footer cover">
#         <div class="news cover">
#             <div class="top-news"></div>
#             <div class="footer-content cover">
#                 <div class="right users">
#                     <span class="icon"></span>
#                      <div class="title">
#                         مشتریان ایران سرور چه می گویند؟
#                     </div>
#                     <p class="scrollpan"></p>
#                     <p class="chng-style">
#                         <span></span>
#                         <em class="user-name"></em>
#                         <!-- آقای فرزاد -->
#                     </p>
#                 </div>
#                 <div class="shadow"></div>
#                 <div class="right news-content">
#                     <span class="icon"></span>
#                     <div class="title right">
#                         چه خبر؟
#                     </div>
#                     <div id="gh_tab_menue" class="font-face-yekan">
#
#                         <ul class="nav">
#                             <li class="nav-one"><a href="#tab_one" class="current">تمام اخبار<span class="icon-active"></span></a></li>
#                             <li class="nav-two"><a href="#tab_two">از وبلاگ<span class="icon-active"></span></a></li>
#                         </ul>
#
#                        <div class="list-wrap" >
#                             <ul id="tab_one" class="scrollpan">
#
# 		<li>
# 			<a target="_blank" href="https://hub.iranserver.com/announcements.php?id=111"><span class="icon-tabmenu"></span>تغییر در هزینه تمدید سرویس‌ها</a>
# 		</li>
#
#
# 		<li>
# 			<a target="_blank" href="https://hub.iranserver.com/announcements.php?id=110"><span class="icon-tabmenu"></span>صدور ویزا کارت</a>
# 		</li>
#
#
# 		<li>
# 			<a target="_blank" href="https://hub.iranserver.com/announcements.php?id=109"><span class="icon-tabmenu"></span>تغییر در شرایط پشتیبانی</a>
# 		</li>
#
#
# 		<li>
# 			<a target="_blank" href="https://hub.iranserver.com/announcements.php?id=108"><span class="icon-tabmenu"></span>نمایندگی رسمی WHMCS - قیمت استثنایی لایسنس</a>
# 		</li>
#
#
# 		<li>
# 			<a target="_blank" href="https://hub.iranserver.com/announcements.php?id=107"><span class="icon-tabmenu"></span>اضافه شدن AntiDDOS بروی سرورهای آلمان</a>
# 		</li>
#
#
# 		<li>
# 			<a target="_blank" href="https://hub.iranserver.com/announcements.php?id=106"><span class="icon-tabmenu"></span>ایران سرور در نمایشگاه بین‌المللی کامپیوتر و شهرهوشمند</a>
# 		</li>
#
#
# 		<li>
# 			<a target="_blank" href="https://hub.iranserver.com/announcements.php?id=105"><span class="icon-tabmenu"></span>تخفیف ویژه ثبت دامنه</a>
# 		</li>
#
#
# 		<li>
# 			<a target="_blank" href="https://hub.iranserver.com/announcements.php?id=104"><span class="icon-tabmenu"></span>زین پس بلاگ ما را ایمن مطالعه نمایید</a>
# 		</li>
#
#
# 		<li>
# 			<a target="_blank" href="https://hub.iranserver.com/announcements.php?id=103"><span class="icon-tabmenu"></span>مالیات برارزش افزوده و فاکتور رسمی</a>
# 		</li>
#
#
# 		<li>
# 			<a target="_blank" href="https://hub.iranserver.com/announcements.php?id=102"><span class="icon-tabmenu"></span>تخفیف ویژه ثبت دامنه تا نیمه شعبان</a>
# 		</li>
#
# 	                            </ul>
#                              <ul id="tab_two" class="scrollpan">
#
# 		<li>
# 			<a target="_blank" href="https://blog.iranserver.com/%D8%A7%D9%86%D8%AA%D9%82%D8%A7%D9%84-%D8%AF%D8%A7%D9%85%D9%86%D9%87/"><span class="icon-tabmenu"></span>قوانین جدید انتقال دامنه</a>
# 		</li>
#
#
# 		<li>
# 			<a target="_blank" href="https://blog.iranserver.com/%DA%86%D8%B1%D8%A7-%D8%A8%D8%A7%DB%8C%D8%AF-ssl-%D8%AF%D8%A7%D8%B4%D8%AA%D9%87-%D8%A8%D8%A7%D8%B4%DB%8C%D9%85%D8%9F/"><span class="icon-tabmenu"></span>چرا باید SSL داشته باشیم؟</a>
# 		</li>
#
#
# 		<li>
# 			<a target="_blank" href="https://blog.iranserver.com/%D8%A2%D9%85%D9%88%D8%B2%D8%B4-%D9%85%D9%87%D8%A7%D8%AC%D8%B1%D8%AA-%D8%AC%D9%88%D9%85%D9%84%D8%A7/"><span class="icon-tabmenu"></span>آموزش مهاجرت جوملا ۲٫۵ به ۳٫x – بخش دوم</a>
# 		</li>
#
#
# 		<li>
# 			<a target="_blank" href="https://blog.iranserver.com/%D8%B3%D8%B1%D9%88%DB%8C%D8%B3-%D9%87%D8%A7%DB%8C-%D8%B4%D8%B1%DA%A9%D8%AA-%D9%87%D8%A7%DB%8C-%D9%87%D8%A7%D8%B3%D8%AA%DB%8C%D9%86%DA%AF/"><span class="icon-tabmenu"></span>۸ سرویس متداول شرکت های میزبانی وب</a>
# 		</li>
#
#
# 		<li>
# 			<a target="_blank" href="https://blog.iranserver.com/cpanel-%DA%86%DB%8C%D8%B3%D8%AA%D8%9F/"><span class="icon-tabmenu"></span>cPanel چیست؟</a>
# 		</li>
#
#
# 		<li>
# 			<a target="_blank" href="https://blog.iranserver.com/%D8%A8%D9%87%DB%8C%D9%86%D9%87-%D8%B3%D8%A7%D8%B2%DB%8C-%D9%88%D8%A8-%D8%B3%D8%B1%D9%88%D8%B1-nginx-%D8%A8%D8%AE%D8%B4-%D8%A2%D8%AE%D8%B1/"><span class="icon-tabmenu"></span>بهینه سازی وب سرور Nginx – بخش آخر</a>
# 		</li>
#
#
# 		<li>
# 			<a target="_blank" href="https://blog.iranserver.com/%D9%88%DB%8C%D8%B1%D9%88%D8%B3-%D8%A8%D8%A7%D8%AC%DA%AF%DB%8C%D8%B1-petya-%D8%B1%D8%A7-%D8%A8%DB%8C%D8%B4%D8%AA%D8%B1-%D8%A8%D8%B4%D9%86%D8%A7%D8%B3%DB%8C%D8%AF/"><span class="icon-tabmenu"></span>ویروس باجگیر petya را بیشتر بشناسید</a>
# 		</li>
#
#
# 		<li>
# 			<a target="_blank" href="https://blog.iranserver.com/%D8%A7%D9%86%D8%AA%D9%82%D8%A7%D9%84-%D8%A7%D9%85%D9%86-%D8%A7%D8%B7%D9%84%D8%A7%D8%B9%D8%A7%D8%AA-%D8%AA%D9%88%D8%B3%D8%B7-filezilla-%D8%A7%D8%B2-%D8%B7%D8%B1%DB%8C%D9%82-sftp/"><span class="icon-tabmenu"></span>انتقال امن اطلاعات توسط filezilla از طریق SFTP</a>
# 		</li>
#
#
# 		<li>
# 			<a target="_blank" href="https://blog.iranserver.com/%D8%A7%D9%86%D8%AA%D9%82%D8%A7%D9%84-%D8%A7%D9%85%D9%86-%D8%A7%D8%B7%D9%84%D8%A7%D8%B9%D8%A7%D8%AA/"><span class="icon-tabmenu"></span>انتقال امن اطلاعات</a>
# 		</li>
#
#
# 		<li>
# 			<a target="_blank" href="https://blog.iranserver.com/%D9%85%DB%8C%D8%B2%D8%A8%D8%A7%D9%86%DB%8C-%D9%88%D8%A8-%DA%86%DB%8C%D8%B3%D8%AA/"><span class="icon-tabmenu"></span>میزبانی وب چیست</a>
# 		</li>
#
# 	                             </ul>
#                         </div> <!-- END List Wrap -->
#                     </div> <!-- END Organic Tabs (Example One) -->
#                 </div>
#             </div>
#         </div>
#         <div class="bg-slide">
#             <div class="right">
#
#             </div>
#             <div class="slide">
#                 <div class="next"></div>
#                 <div class="prev"></div>
#                 <div class="inside-slide">
#                     <ul>
#                         <li><img src="http://iranserver.com/img/slide_logo/amozesh-estesnaee.jpg" width='80' height='80'   alt="iranserver-amozesh-estesnaee" /></li>
#                         <li><img src="http://iranserver.com/img/slide_logo/arvand.jpg"   width='78' height='80' alt="iranserver-arvand" /></li>
#                         <li><img src="http://iranserver.com/img/slide_logo/azad-sistan.jpg"  width='78' height='80' alt="iranserver-azad-sistan" /></li>
#                         <li><img src="http://iranserver.com/img/slide_logo/bonyad-maskan-en.jpg"  width='76' height='80' alt="iranserver-bonyad-maskan-en" /></li>
#                         <li><img src="http://iranserver.com/img/slide_logo/esfahan-fair.jpg"  width='84' height='80'  alt="iranserver-esfahan-fair" /></li>
#                         <li><img src="http://iranserver.com/img/slide_logo/gomrok.jpg"  width='78' height='80' alt="iranserver-gomrok" /></li>
#                         <li><img src="http://iranserver.com/img/slide_logo/hamyarihaye-shahrdariha.jpg"  width='82' height='78' alt="iranserver-hamyarihaye-shahrdariha" /></li>
#                         <li><img src="http://iranserver.com/img/slide_logo/hotel-ghasr.jpg"  width='90' height='75' alt="iranserver-hotel-ghasr" /></li>
#                         <li><img src="http://iranserver.com/img/slide_logo/jahad.jpg"  width='92' height='80' alt="iranserver-jahad" /></li>
# ...
#             </ul>
#         </div>
#         <div class="footer_links_logo cover">
#             <div class="links_logo_new"></div>
#             <div class="info-footer font-face-yekan cover">
#                 <div class="footer-icon cover">
#                     <div class="footer-logo-iranserver">
#                         <a href="http://iranserver.com/" onclick="ga('send', 'event', 'footer', 'logo');">
#                             ایران‌سرور
#                         </a>
#                     </div>
#                     <ul class="social-icon cover">
#                         <li><a href="https://hub.iranserver.com/announcementsrss.php" target="_blank" class="rss" onclick="ga('send', 'event', 'social', 'rss');"></a></li>
#                         <li><a href="https://www.facebook.com/iranserver" class="facebook" target="_blank" onclick="ga('send', 'event', 'social', 'facebook');"></a></li>
#                         <li><a href="https://twitter.com/iranserver" class="twiter" target="_blank" onclick="ga('send', 'event', 'social', 'twitter');"></a></li>
#                         <li><a href="https://www.linkedin.com/company/iranserver" target="_blank" class="linkedin" onclick="ga('send', 'event', 'social', 'linkedin');"></a></li>
#                         <li><a href="https://www.instagram.com/iranserver/" class="instagram" target="_blank" onclick="ga('send', 'event', 'social', 'instagram');"></a></li>
#                         <li><a href="http://www.aparat.com/iranserver" class="aparat" target="_blank" onclick="ga('send', 'event', 'social', 'aparat');"></a></li>
#                     </ul>
#                 </div>
#                 <ul>
#                     <li><h3><a href="http://iranserver.com/web-hosting/" title="هاست">هاست</a></h3></li>
#                     <li><a href="http://iranserver.com/web-hosting/">میزبانی وب</a></li>
#                     <li><a href="http://iranserver.com/web-hosting/linux/">هاست لینوکس</a></li>
#                     <li><a href="http://iranserver.com/web-hosting/windows/">هاست ویندوز</a></li>
#                     <li><a href="http://iranserver.com/web-hosting/download/">هاست دانلود</a></li>
#                     <li><a href="http://iranserver.com/web-hosting/wordpress/">هاست وردپرس</a></li>
#                     <li><a href="http://iranserver.com/web-hosting/organizations/">هاست سازمانی</a></li>
#                     <li><a href="http://iranserver.com/other-services/seminars-free-webhosting/">هاست رایگان</a></li>
#                     <li><a href="http://iranserver.com/web-hosting/windows/">هاست دات‌نت نیوک</a></li>
#                     <li><a href="http://iranserver.com/web-hosting/email-hosting/">میزبانی ایمیل</a></li>
#                     <li><a href="http://iranserver.com/web-hosting/linux-reseller/">نمایندگی هاست لینوکس</a></li>
#                     <li><a href="http://iranserver.com/web-hosting/windows-reseller/">نمایندگی هاست ویندوز</a></li>
#                 </ul>
#                 <ul>
#                     <li><h3><a href="http://iranserver.com/domains/" title="ثبت دامنه">ثبت دامنه</a></h3></li>
#                     <li><a href="http://iranserver.com/domains/">ثبت دامین</a></li>
#                     <li><a href="http://iranserver.com/domains/tld/">ثبت دامنه های عمومی</a></li>
#                     <li><a href="http://iranserver.com/domains/ir/">ثبت دامنه های ایرانی</a></li>
#                     <li><a href="http://iranserver.com/domains/persian/">ثبت دامنه فارسی</a></li>
#                     <li><a href="http://iranserver.com/domains/backorder/">رزرو دامنه</a></li>
#                     <li><a href="http://iranserver.com/domains/auction/">حراج دامنه</a></li>
#                     <li><a href="http://iranserver.com/domains/reseller/">نمایندگی ثبت دامنه</a></li>
#                     <li><a href="http://iranserver.com/domains/registrar/">مشخصات مرکز ثبت</a></li>
#                     <!-- <li><a href="http://iranserver.com/promotions/">فروش ویژه</a></li> -->
#                 </ul>
#                 <ul>
#                     <li><h3><a href="http://iranserver.com/vps/" title="سرور مجازی">سرور مجازی</a></h3></li>
#                     <li><a href="http://iranserver.com/vps/iran/">سرور مجازی ایران</a></li>
#                     <li><a href="http://iranserver.com/vps/europe/">سرور مجازی اروپا</a></li>
#                     <li><a href="http://iranserver.com/vps/ibm/">سرور مجازی ابری IBM</a></li>
#                     <li><a href="http://iranserver.com/vps/vps-management/">مدیریت سرور مجازی</a></li>
#                     <li><a href="http://iranserver.com/vps/compare/">مقایسه سرورهای مجازی</a></li>
#                     <li><a href="http://iranserver.com/vps/">سرور مجازی ویندوز</a></li>
#                     <li><a href="http://iranserver.com/vps/">سرور مجازی لینوکس</a></li>
#                 </ul>
#                 <ul>
#                     <li><h3><a href="http://iranserver.com/dedicated-server/" title="سرور اختصاصی">سرور اختصاصی</a></h3></li>
#                     <li><a href="http://iranserver.com/dedicated-server/iran/">سرور اختصاصی ایران</a></li>
#                     <li><a href="http://iranserver.com/dedicated-server/germany/">سرور اختصاصی آلمان</a></li>
#                     <li><a href="http://iranserver.com/dedicated-server/france/">سرور اختصاصی فرانسه</a></li>
#                     <li><a href="http://iranserver.com/dedicated-server/canada/">سرور اختصاصی کانادا</a></li>
#                     <li><a href="http://iranserver.com/dedicated-server/usa/">سرور اختصاصی آمریکا</a></li>
#                     <li><a href="http://iranserver.com/dedicated-server/ibm/">سرور اختصاصی IBM</a></li>
#                     <li><a href="http://iranserver.com/dedicated-server/server-management/">مدیریت سرور اختصاصی</a></li>
#                     <li><a href="http://iranserver.com/dedicated-server/co-location/" target="_blank">فضای رک</a></li>
#                     <li><a href="http://iranserver.com/datacenter-tour/">معرفی دیتاسنتر</a></li>
#                     <li><a href="http://iranserver.com/dedicated-server/compare/">مقایسه سرورهای اختصاصی</a></li>
#                 </ul>
#                 <ul>
#                     <li><h3><a href="http://iranserver.com/other-services/" title="دیگر خدمات">دیگر خدمات</a></h3></li>
#                     <li><a href="http://iranserver.com/other-services/server-management/">پشتیبانی فنی سرور</a></li>
#                     <li><a href="http://iranserver.com/other-services/ssl-certificates/">گواهی دیجیتال SSL</a></li>
#                     <li><a href="http://iranserver.com/other-services/seminars-free-webhosting/">همایش‌های علمی</a></li>
#                     <!-- <li><a href="other-services/paypal-payments/">پرداخت اینترنتی پی‌پال</a></li> -->
#                     <li><a href="http://iranserver.com/host-domain-buying-guide/">راهنمای خرید</a></li>
#                     <li><a href="http://iranserver.com/control-panel/">کنترل‌پنل مدیریت هاستینگ</a></li>
#                     <li><a href="http://iranserver.com/other-services/license/">لایسنس</a></li>
#                     <li><a href="http://iranserver.com/other-services/hardware/">سخت افزار</a></li>
#                     <li><a href="http://iranserver.com/promotions/" target="_blank">فروش ویژه</a></li>
#                     <li><a href="http://iranserver.com/support/" target="_blank">پشتیبانی نرم افزاری</a></li>
#                     <li><a href="http://iranserver.com/website-transfer/" target="_blank" title="انتقال هاست سایت و سرور ">انتقال</a></li>
#                 </ul>
#             </div>
#         </div>
#         <div class="copy_right font-face-yekan cover">
#             <div class="content-copy_right cover">
#                 <div class="right txt-copy-right">
#                     <p><a class="logo-greenweb" ></a><a target="_blank" href="http://www.greenweb.ir" title="طراحی سایت مشهد">طراحی سایت</a> و <a href="http://www.tabliq.com" target="_blank" data-hover="بهینه سازی" title="طراحی سایت مشهد">بهینه سازی</a> سایت توسط <a href="http://www.greenweb.ir" target="_blank" class="greenweb" title="طراحی سایت مشهد" data-hover="گرین وب">گرین وب</a></p>
#                 </div>
#                 <div class="left">
#                     <ul class="cover">
#                         <li><a href="http://iranserver.com/" title=" سرور">صفحه اصلی</a></li>
#                         <li><a href="https://hub.iranserver.com/" target="_blank">پورتال مشتریان</a></li>
#                         <li><a href="http://iranserver.com/about-us/">درباره ایران سرور</a></li>
#                         <li><a target="_blank" href="http://blog.iranserver.com">وبلاگ</a></li>
#                         <!-- <li><a href="http://iranserver.com/term-of-service/">شرایط استفاده از خدمات</a></li> -->
#                         <li><a href="http://www.greenweb.ir/job/" target="_blank">استخدام</a></li>
#                         <!-- <li><a href="http://iranserver.com/support/" >پشتیبانی</a></li> -->
#                         <li><a href="http://iranserver.com/documents/sla.pdf" target="_blank">تضمین کیفیت</a></li>
#                         <li><a href="https://hub.iranserver.com/bank-account-number.php" target="_blank">شماره حساب‌ها</a></li>
#                         <li><a href="http://iranserver.com/contact-us/">تماس</a></li>
#                     </ul>
#                 </div>
#             </div>
#         </div>
#     </div><!-- ./footer -->
#
#             <script src="http://iranserver.com/js/jquery.min.js" type="text/javascript"></script>
#         <script src="http://iranserver.com/js/jcarousellite_1.0.1c4.js" type="text/javascript"></script>
#     <script src="http://iranserver.com/js/organictabs.jquery.js" type="text/javascript"></script>
#     <script src="http://iranserver.com/js/jquery.mCustomScrollbar.concat.min.js"></script>
#     <script src="http://iranserver.com/js/jquery.scrolldepth.min.js"></script>
#     <script src="http://iranserver.com/js/feedback.js"></script>
#     <!-- for index.php -->
#
#
#
#
#
#
#
#         <script src="http://iranserver.com/js/tipso.min.js"></script>
#     <script src="http://iranserver.com/js/script-inside.js"></script>
#     <!-- // <script src="http://iranserver.com/js/jquery.tipTip.min.js"></script> -->
#
#     <!-- for promotions folder and datacenter -->
#     <script src="http://iranserver.com/js/jquery.prettyPhoto.js"></script>
#
#
#    <script>
#
#       (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#       (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#       m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#       })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#       ga('create', 'UA-2253268-2', 'iranserver.com');
#       ga('send', 'pageview');
#
# </script>
#  <script>
# jQuery(function() {
#   jQuery.scrollDepth();
# });
# </script>
#
#  <script type=text/javascript>
#     <!--
#     function OpenCertDetails()
#     {
#     thewindow =
#     window.open('http://www.elecitex.com/passport/excellence/2012?ID=2012-hyYZxX8X34&DN=iranserver.com&SEALID=8MiP3A1XE9&TYPE=GOLD',
#     'anew', config='toolbar=0,location=1,directories=0,status=0,menubar=0,scrollbars=0,resizable=0,width=522,height=660');
#     }
#     -->
# </script>
#
# <script type="text/javascript">
# $(function(){
#
#     var nazar=['ایران‌سرور به نظر من بهترین سرویس دهنده میزبانی وب در ایران هست و در این مدت که با هم همکاری داشتیم از نظر پشتیبانی عالی بوده و به طور قطع انجمن ما کمترین مشکلات را در طول دوران فعالیتش در ایران سرور تجربه کرده‌است.',' حقیقتاً تا به حال از هیچ سرویس دهنده خدمات وب تشکر نکردم چرا که ارائه خدمات رو وظیفه ذاتی شرکت های ارائه خدمات وب می دونم، اما در مورد ایران سرور، انگار پشتیبانی وظیفه نیست، بلکه یک هدف والا است که در کنار خدمات بسیار مناسب، دلگرمی خاصی به مشتریان میده. دلگرمی به این که «خیالتون راحت، ایران سرور یعنی پشتیبانی بی نظیر!»','بی نهایت ممنون از پشتیبانی سریع و عالیتون، واقعا خیلی راضیم که از سرویس‌های شما استفاده می‌کنم. رضایت منو از بخش پشتیبانی به گوش مدیران محترمتون برسونید. سرافراز و موفق باشید.','با سلام، از همکاری شما نهایت سپاسگذاری را دارم، واقعا شرکت شما در زمینه پشتیبانی فوق العاده است. متشکرم','از موقعی که طراحی وب رو بعنوان یه کار جدی شروع کردم ، یکی از مواردی که هیچ وقت خودم رو درگیرش نمیکردم، مسئله خرید هاست و دومین واسه مشتریانم بود.بعد از تجربه‌های ناموفق خودم و دوستان از درگیری و مشکلات متعدد با هاستینگ‌های مختلف (چه ایرانی و چه خارجی) و همچنین مسائل و مشکلات پیرامون دلار و نحوه پرداخت هزینه هاست‌های خوب خارجی، خیلی اتفاقی با یک هاستینگ خوب داخلی، ایرانی-مشهدی آشنا شدم.اوایل نسبت به این هاستینگ هم کاملا بی اعتماد بودم، ولی با توجه به عملکرد فوق العاده عالیشون در این چند وقت، به درجه‌ای از اعتماد رسیدم که میخوام از همین تریبون واسشون تبلیغات هم انجام بدم.پس شما هم اگر بدنبال یک هاستینگ قدرتمند هستید، پیشنهاد میکنم که حتما به مجموعه ایران‌سرور مراجعه کنید.پ.ن: در هفته اخیر ۲ سفارش پشتیبانی داشتیم که یکی از شروط ما برای قبول پشتیبانی، انتقال هاست به سرورهای قدرتمند IranServer بود.','با سلام جا داره از پشتیبانی های خوب همکاران ایران سرور تشکر و قدردانی کنم. جواب اعتماد به ایران سرور رو دیدم و به دیگران معرفی خواهم کرد. سپاس','سرعت پاسخگوئی و همکاری و کمک های پرسنل ایران سرور در نوع خودش بی نظیره. بعنوان یک کاربر ساکن اروپا از اینکه از خدمات این شرکت استفاده میکنیم خیلی راضی هستیم.','با سلام واقعا از ایران سرور راضی هستم و از پشتیبانی قوی اینران سرور کمال تشکر رو دارم، خیلی سریع و بدون معطلی جواب تمام تیکت هارو میدن، جا داره بهشون خسته نباشید بگم واقعا خسته نباشید. امیدوارم همیشه موفق و پیروز باشین.','با سلام واقعا از تیم پشتیبانی ایران سرور تشکر می کنم. خیلی سریع و دلسوزانه مشکلات رو حل میکنن.', 'با سلام  تشكر از خدماتتون  ياعلي','باید بگم بهترین پشتیبانی سایتی که تو عمرم دیدم رو این سایت داره الان چندروزه یه مشکل برا سایتم پیش اومده بود که مسئولان پشتیبانی با صبر و حوصله مشکلم رو حل کردن کمال تشکر رو ازشون دارم.','سلام میخواستم راجع به تیکت شماره 567550 با موضوع بازگردانی اطلاعات از بین روفته روی سرورم بگم که واقعا خوب و تحسین بر انگیز از ما پشتیبانی کردین و به طور مخصوص میخواستم از خانم تقوی که تو رفع  این مشکل کنار ما بودن تشکر کنم. خانم تقوی از شما متشکرم. خیلی زحمت کشیدید. پشتیبانی و خدمات پس از فروش رو خیلی خوب معنی کردین.','چند روزی هست که مدام در حال تیکت زدن هستم و در بعضی موارد هم من متوجه توضیحات همکاران نمی شدم و هم نمیتونستم خوب منظورم را برسانم ، اما با زحمات و کمک های همکاران ایران سرور ، مشکل من مرتفع گشت. جای خوشحالی است شرکت هایی این چنین هرچند اندک ، اما در حال خدمات رسانی و ارزش گذاری برای مشتریانشان هستن از همگی شما ممنونم','با سلام و خسته نباشید شرکت بنده بمدت 4 سال است که نماینده فروش محصولات ایران سرور هست . واقعا پشتیبانی ایران سرور حرف نداره . بنده با شرکت های مختلفی کار کردم . اما پشتیبانی ایران سرور واقعا حرف نداره . انشا... همیشه موفق و سربلند باشید .','وقت بخیر مایه مباهات است که اطلاعات هاست ما بر روی سرور شرکتی می باشد که در قبال مشتریان خود احساس مسئولیت می کند و در هر ساعت از شبانه روز، در کمترین زمان ممکن نسبت به پیگیری و رفع مشکل توسط کارشناسان خبره اقدام می نماید.شاید باشید.' ,'با عرض سلام احتراما اینجانب مدیریت نگین سفال اصفهان کمال تشکر خود را از پرسنل و تیم زحمت کش ایران سرور ابراز می دارم، من خود 34 سال دارم و حدود 20 سال سابقه در زمینه سایت و مدیریت آنرا دارا می باشم . سایت جدید من sofalnegin.ir است که از عید سال گذشته تا بحال مجبور به سه بار جابجایی هاست در ارایه دهندگان خدمات مختلف شده ام و این بار ششم است که برای یک سایت سرور عوض نموده ام . در م ...
#     var name=['انجمن تعمیرکاران ایران (irantk.ir)','آقای فرزاد','آقای گودرزی منش (باران استودیو)',' آقای اباذری','احسان ثابت - مدرس آکادمی تخصصی IT گستره دانش','جواد صابری از شرکت -ا فرو','سام از شرکت  -ایرانیا','مهدی حق خواه از شرکت - گروه صنعتی زیست پایش','وحید رباطی از شرکت رایان تکسان','مجيد پارساييان از شرکت گروه پارسا','امین منفرد از شرکت www.zinatkadeh.ir','محمود خواجه پور از شرکت فروشگاه اینترنتی فرافایل','فرزان اسکندری-پارت رایان','سید مسعود موسوی -گروه تجاری هزاره سوم','هادی پایدار-هتل بزرگ سی نور','محمد حسین شرکت قناد - شرکت نگین سفال اصفهان'];
#
#     var x = Math.floor((Math.random() * (nazar.length)));
#
#     $('.users .scrollpan').text(nazar[x]);
#     $('.users .chng-style .user-name').text(name[x]);
#     $(".users .scrollpan").mCustomScrollbar({
#         autoHideScrollbar:true,
#         theme:"light-thin"
#     });
# })
# </script>
#     </body>
# </html>

# %%
import pandas as pd

dic = "https://docs.google.com/spreadsheets/d/18nWiecKkH7Oj5c2yPrqZPq5cFyieJeowVyCK107ZOYM/pub?gid=0&single=true&output=csv"
data = pd.read_csv(dic)

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(content, 'html.parser')
table = soup.find("table", {"class" : "panels tahoma"})
table2 = soup.find("table", {"class" : "tahoma tbl"})

        
count = len(table.findAll('tr')[0].findAll('td'))
records = []
for tr in table.findAll("tr"):
    trs = tr.findAll("td")
    record = []
    for i in range (count):
        record.append(trs[i].text)
    
    records.append(record)

    
for tr in table2.findAll("tr"):
    if tr.find(class_='titr'):
        continue
    trs = tr.findAll("td")
    record = []
    for i in range (count):
        if(trs[i].text!=""):
            record.append(trs[i].text)
        else:
            record.append(trs[i].span['class'])
        
    
    records.append(record)

    
df = pd.DataFrame(data=records)
df
# Out:
#                                         0                     1  \
# 0                                نام سرور               ایران۷
# 1                                     CPU             Xeon 3430
# 2                                     RAM           ۸  گیگابایت
# 3                               هارد دیسک           2x500G SATA
# 4                             پهنای باند             ۱۰۰ مگابیت
# 5                         ترافیک ماهیانه              ۱ ترابایت
# 6                               دیتاسنتر   پارس آنلاین / افرانت
# 7                                پشتیبانی                سطح یک
# 8                               کنترل پنل               انتخابی
# 9                              سیستم عامل               انتخابی
# 10                                   برند                  Asus
# 11                    مدت تحویل (روزکاری)                ۱ تا ۳
# 12             هزینه‌ی راه‌اندازی (تومان)                ۵۰,۰۰۰
# 13                هزینه‌ی ماهیانه (تومان)               ۴۰۲,۵۰۰
# 14                         قیمت سخت افزار             کلیک کنید
# 15  تمـام قـیمت هـــــا به تومان می باشد.                 سفارش
# 16                         تعداد CPU Core                     ۴
# 17                      تعداد CPU Threads                     ۴
# 18                      سرعت پردازش (GHz)                   2.4
# 19                      امکان مجازی‌سازی                 جزئیات
# 20                 امکان RAID سخت‌افزاری                   [ok]
# 21                  امکان RAID نرم‌افزاری                  [ok]
# 22                         سرعت کارت شبکه             ۱ گیگابیت
# 23                               اینترانت              انتخابی
# 24                    تعداد اتصال به شبکه               یک عدد
# 25                           زیرساخت شبکه       Cisco Catalyst
# 26                          تعداد آدرس IP               یک عدد
# 27                     حداکثر تعداد IP تک                 ۵ عدد
# 28                       هزینه‌ی IP اضافه         ۵,۰۰۰ تومان
# 29                   حداکثر IP در بلاک IP                ۳۲ عدد
# 30                       کنترل پنل رایگان           DirectAdmin
# 31                  CXS AntiShell (تومان)                ۲۰,۰۰۰
# 32                     گارانتی بازگشت وجه                 ۱۵روز
# 33                          انتقال رایگان                جزئیات
# 34                              ارائه KVM          در صورت نیاز
# 35                          دسترسی Reboot                 [err]
# 36                          دسترسی Rescue                  [ok]
# 37                  امکان نصب مجدد رایگان                  [ok]
# 38                    فضای پشتیبان رایگان          ۱۰۰ گیگابایت
# 39                  دسترسی به گراف ترافیک                  [ok]
# 40                    مانیتورینگ سرویس‌ها                  [ok]
# 41  تمـام قـیمت هـــــا به تومان می باشد.                 سفارش
#
#                        2                        3                     4  \
# 0                ایران۲۰                 ایران ۲۲               ایران۱۴
# 1             Xeon L5520                Xeon 5540         2x Xeon L5520
# 2            ۲۴ گیگابایت             ۳۲ گیگابایت            ۳۲ گیگابایت
# 3             2x1TB SATA  2x1TB SATA + 2x240G SSD            2x1TB SATA
# 4             ۱۰۰ مگابیت               ۱۰۰ مگابیت            ۱۰۰ مگابیت
# 5              ۳ ترابایت                ۳ ترابایت             ۳ ترابایت
# 6   پارس آنلاین / افرانت     پارس آنلاین / افرانت  پارس آنلاین / افرانت
# 7                 سطح یک                   سطح یک                سطح یک
# 8                انتخابی                  انتخابی               انتخابی
# 9                انتخابی                  انتخابی               انتخابی
# 10                    HP                       HP                    HP
# 11                ۱ تا ۳                   ۱ تا ۳                ۱ تا ۳
# 12                ۵۰,۰۰۰                   ۵۰,۰۰۰                ۵۰,۰۰۰
# 13               ۴۷۲,۰۰۰                  ۶۷۸,۵۰۰               ۶۷۸,۵۰۰
# 14             کلیک کنید                کلیک کنید             کلیک کنید
# 15                 سفارش                    سفارش                 سفارش
# 16                     ۴                        ۴                   ۲x۴
# 17                     ۸                        ۸                   ۲x۸
# 18                  2.26                     2.53                  2.26
# 19                جزئیات                   جزئیات                جزئیات
# 20                  [ok]                     [ok]                  [ok]
# 21                  [ok]                     [ok]                  [ok]
# 22             ۱ گیگابیت                ۱ گیگابیت             ۱ گیگابیت
# 23              انتخابی                  انتخابی               انتخابی
# 24               یک عدد                   یک عدد                یک عدد
# 25        Cisco Catalyst           Cisco Catalyst       Cisco Catalyst
# 26                یک عدد                   یک عدد               یک عدد
# 27                 ۵ عدد                    ۵ عدد                 ۵ عدد
# 28           ۵,۰۰۰ تومان              ۵,۰۰۰ تومان           ۵,۰۰۰ تومان
# 29                ۳۲ عدد                   ۳۲ عدد                ۳۲ عدد
# 30           DirectAdmin              DirectAdmin           DirectAdmin
# 31                ۲۰,۰۰۰                   ۲۰,۰۰۰                ۲۰,۰۰۰
# 32                 ۱۵روز                    ۱۵روز                 ۱۵روز
# 33                جزئیات                   جزئیات                جزئیات
# 34          در صورت نیاز             در صورت نیاز          در صورت نیاز
# 35                  [ok]                     [ok]                  [ok]
# 36                  [ok]                     [ok]                  [ok]
# 37                  [ok]                     [ok]                  [ok]
# 38          ۱۰۰ گیگابایت             ۱۰۰ گیگابایت          ۱۰۰ گیگابایت
# 39                  [ok]                     [ok]                  [ok]
# 40                  [ok]                     [ok]                  [ok]
# 41                 سفارش                    سفارش                 سفارش
#
#                        5
# 0                ایران۱۹
# 1            2x Xeon5650
# 2            ۷۲ گیگابایت
# 3              4x1TB SAS
# 4             ۱۰۰ مگابیت
# 5              ۳ ترابایت
# 6   پارس آنلاین / افرانت
# 7                 سطح یک
# 8                انتخابی
# 9                انتخابی
# 10                    HP
# 11                ۱ تا ۳
# 12                ۵۰,۰۰۰
# 13             ۱,۱۳۸,۰۰۰
# 14             کلیک کنید
# 15                 سفارش
# 16                   ۲x۶
# 17                  ۲x۱۲
# 18                  2.66
# 19                جزئیات
# 20                  [ok]
# 21                  [ok]
# 22             ۱ گیگابیت
# 23              انتخابی
# 24               یک عدد
# 25        Cisco Catalyst
# 26                یک عدد
# 27                 ۵ عدد
# 28           ۵,۰۰۰ تومان
# 29                ۳۲ عدد
# 30           DirectAdmin
# 31                ۲۰,۰۰۰
# 32                 ۱۵روز
# 33                جزئیات
# 34          در صورت نیاز
# 35                  [ok]
# 36                  [ok]
# 37                  [ok]
# 38          ۱۰۰ گیگابایت
# 39                  [ok]
# 40                  [ok]
# 41                 سفارش

# %%
df.T.to_csv("data.csv")
# df.T.to_csv("data.csv",sep='\t', encoding='utf-8')
