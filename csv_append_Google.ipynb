# %%
import pandas as pd
from openpyxl import load_workbook

file_xlsx = "https://docs.google.com/spreadsheets/d/18nWiecKkH7Oj5c2yPrqZPq5cFyieJeowVyCK107ZOYM/pub?output=xlsx"
CLEAN = pd.read_excel(file_xlsx, 'CLEAN', index_col=None, na_values=['NA'])
CLEAN
# Out:
#   SERVICENAME     RAM    DISKTYPE    DISK VIRTUALIZATION     BW TRAFFIC    DC  \
# 0      VIR013  1.5 GB  SATA / SAS   50 GB            KVM  10 Mb   45 GB  IRAN
# 1      VIR014    3 GB  SATA / SAS  150 GB            KVM  10 Mb  335 GB  IRAN
# 2      VIR015    4 GB  SATA / SAS  175 GB            KVM  10 Mb  405 GB  IRAN
# 3      VIR016    5 GB  SATA / SAS  200 GB            KVM  10 Mb  475 GB  IRAN
#
#               OS  CPU SERVICETYPE                         PROVIDERLINK  \
# 0          Linux    2         VPS  http://www.iranserver.com/vps/iran/
# 1  Linux/Windows    2         VPS  http://www.iranserver.com/vps/iran/
# 2  Linux/Windows    2         VPS  http://www.iranserver.com/vps/iran/
# 3  Linux/Windows    2         VPS  http://www.iranserver.com/vps/iran/
#
#    INSTALLATION  OPERATION
# 0          2000       2000
# 1          2000       2000
# 2          2000       2000
# 3          2000       2000

# %%
book = load_workbook(file_xlsx)
writer = pandas.ExcelWriter(file_xlsx, engine='openpyxl') 
writer.book = book
writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

df.to_excel(writer, 'CLEAN', startrow=len(df)+2, index=False)
writer.save()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-1071444f65d0> in <module>()
# ----> 1 book = load_workbook(file_xlsx)
#       2 writer = pandas.ExcelWriter(file_xlsx, engine='openpyxl')
#       3 writer.book = book
#       4 writer.sheets = dict((ws.title, ws) for ws in book.worksheets)
#       5
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/openpyxl/reader/excel.py in load_workbook(filename, read_only, use_iterators, keep_vba, guess_types, data_only)
#     149
#     150     """
# --> 151     archive = _validate_archive(filename)
#     152     read_only = read_only or use_iterators
#     153
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/openpyxl/reader/excel.py in _validate_archive(filename)
#     113
#     114     try:
# --> 115         archive = ZipFile(filename, 'r', ZIP_DEFLATED)
#     116     except BadZipfile:
#     117         f = repair_central_directory(filename, is_file_like)
#
# /home/ubuntu/anaconda3/lib/python3.5/zipfile.py in __init__(self, file, mode, compression, allowZip64)
#    1007             while True:
#    1008                 try:
# -> 1009                     self.fp = io.open(file, filemode)
#    1010                 except OSError:
#    1011                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'https://docs.google.com/spreadsheets/d/18nWiecKkH7Oj5c2yPrqZPq5cFyieJeowVyCK107ZOYM/pub?output=xlsx'

# %%
from __future__ import print_function
import httplib2
import os

from apiclient import discovery
from oauth2client import client
from oauth2client import tools
from oauth2client.file import Storage

try:
    import argparse
    flags = argparse.ArgumentParser(parents=[tools.argparser]).parse_args()
except ImportError:
    flags = None

# If modifying these scopes, delete your previously saved credentials
# at ~/.credentials/sheets.googleapis.com-python-quickstart.json
SCOPES = 'https://www.googleapis.com/auth/spreadsheets.readonly'
CLIENT_SECRET_FILE = 'client_secret.json'
APPLICATION_NAME = 'Google Sheets API Python Quickstart'


def get_credentials():
    """Gets valid user credentials from storage.

    If nothing has been stored, or if the stored credentials are invalid,
    the OAuth2 flow is completed to obtain the new credentials.

    Returns:
        Credentials, the obtained credential.
    """
    home_dir = os.path.expanduser('~')
    credential_dir = os.path.join(home_dir, '.credentials')
    if not os.path.exists(credential_dir):
        os.makedirs(credential_dir)
    credential_path = os.path.join(credential_dir,
                                   'sheets.googleapis.com-python-quickstart.json')

    store = Storage(credential_path)
    credentials = store.get()
    if not credentials or credentials.invalid:
        flow = client.flow_from_clientsecrets(CLIENT_SECRET_FILE, SCOPES)
        flow.user_agent = APPLICATION_NAME
        if flags:
            credentials = tools.run_flow(flow, store, flags)
        else: # Needed only for compatibility with Python 2.6
            credentials = tools.run(flow, store)
        print('Storing credentials to ' + credential_path)
    return credentials

def test():
    """Shows basic usage of the Sheets API.

    Creates a Sheets API service object and prints the names and majors of
    students in a sample spreadsheet:
    https://docs.google.com/spreadsheets/d/1BxiMVs0XRA5nFMdKvBdBZjgmUUqptlbs74OgvE2upms/edit
    """
    credentials = get_credentials()
    http = credentials.authorize(httplib2.Http())
    discoveryUrl = ('https://sheets.googleapis.com/$discovery/rest?'
                    'version=v4')
    service = discovery.build('sheets', 'v4', http=http,
                              discoveryServiceUrl=discoveryUrl)

    spreadsheetId = '1BxiMVs0XRA5nFMdKvBdBZjgmUUqptlbs74OgvE2upms'
    rangeName = 'Class Data!A2:E'
    result = service.spreadsheets().values().get(
        spreadsheetId=spreadsheetId, range=rangeName).execute()
    values = result.get('values', [])

    if not values:
        print('No data found.')
    else:
        print('Name, Major:')
        for row in values:
            # Print columns A and E, which correspond to indices 0 and 4.
            print('%s, %s' % (row[0], row[4]))



test()
# Out:
# usage: __main__.py [-h] [--auth_host_name AUTH_HOST_NAME]
#                    [--noauth_local_webserver]
#                    [--auth_host_port [AUTH_HOST_PORT [AUTH_HOST_PORT ...]]]
#                    [--logging_level {DEBUG,INFO,WARNING,ERROR,CRITICAL}]
# __main__.py: error: unrecognized arguments: -f /run/user/1000/jupyter/kernel-7d1968c6-6471-414d-b1d8-1a020aa7c386.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2889: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
